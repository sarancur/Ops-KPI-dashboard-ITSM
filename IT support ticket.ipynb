# %%
import kagglehub
import pandas as pd
import os

path = kagglehub.dataset_download("ahsanneural/synthetic-it-support-tickets")
print("Path:", path)

# Find the CSV
for f in os.listdir(path):
    print("File found:", f)

# Load and inspect
df = pd.read_csv(os.path.join(path, os.listdir(path)[0]))
print("\nShape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nDtypes:\n", df.dtypes)
print("\nSample:\n", df.head(3))
# Out:
# Downloading to /Users/gayathrigmenon/.cache/kagglehub/datasets/ahsanneural/synthetic-it-support-tickets/1.archive...
# 100%|██████████████████████████████████████| 3.55M/3.55M [00:00<00:00, 22.6MB/s]
# Extracting files...
# Path: /Users/gayathrigmenon/.cache/kagglehub/datasets/ahsanneural/synthetic-it-support-tickets/versions/1
# File found: synthetic_it_support_tickets.csv
#
# Shape: (100000, 20)
#
# Columns: ['ticket_id', 'created_at', 'customer_id', 'customer_segment', 'channel', 'product_area', 'issue_type', 'priority', 'status', 'sla_plan', 'initial_message', 'agent_first_reply', 'resolution_summary', 'resolution_time_hours', 'reopened', 'customer_sentiment', 'csat_score', 'has_attachment', 'platform', 'region']
#
# Dtypes:
#  ticket_id                 object
# created_at                object
# customer_id               object
# customer_segment          object
# channel                   object
# product_area              object
# issue_type                object
# priority                  object
# status                    object
# sla_plan                  object
# initial_message           object
# agent_first_reply         object
# resolution_summary        object
# resolution_time_hours    float64
# reopened                   int64
# customer_sentiment        object
# csat_score                 int64
# has_attachment             int64
# platform                  object
# region                    object
# dtype: object
#
# Sample:
#       ticket_id           created_at customer_id customer_segment channel  \
# 0  TCKT_000001  2024-01-31T05:14:27  CUST_00861       individual   email
# 1  TCKT_000002  2024-10-20T06:15:49  CUST_00770       individual  in_app
# 2  TCKT_000003  2024-06-18T21:35:54  CUST_02559   small_business    chat
#
#       product_area        issue_type priority            status  sla_plan  \
# 0      data_export    account_access      low          resolved  standard
# 1          billing  security_concern   medium  closed_no_action  standard
# 2  api_integration               bug      low       in_progress  standard
#
#                                      initial_message  \
# 0  I cannot log in; the system says my password i...
# 1        I noticed a suspicious login on my account.
# 2  The api integration feature is not saving my c...
#
#                                    agent_first_reply  \
# 0  Sorry to hear you're having trouble accessing ...
# 1  We take security very seriously. Our team is r...
# 2  Thanks for reporting this bug. We will look in...
#
#                                   resolution_summary  resolution_time_hours  \
# 0  Reset account credentials and confirmed succes...                  36.53
# 1  Ticket closed without further action after no ...                 238.32
# 2                                                NaN                    NaN
#
#    reopened customer_sentiment  csat_score  has_attachment platform region
# 0         0      very_negative           1               0  android     EU
# 1         0            neutral           3               0      web    NaN
# 2         0            neutral           3               0  android    MEA

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from scipy import stats
import warnings
import os

warnings.filterwarnings('ignore')

# Plot styling — clean, professional
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams.update({
    'figure.dpi': 150,
    'axes.titlesize': 13,
    'axes.labelsize': 11,
    'xtick.labelsize': 9,
    'ytick.labelsize': 9
})

PROCESSED_PATH = '../data/processed/'
VISUALS_PATH   = '../visuals/'
os.makedirs(PROCESSED_PATH, exist_ok=True)
os.makedirs(VISUALS_PATH, exist_ok=True)

print('✅ Environment ready')
# Out:
# ✅ Environment ready

# %%
path = kagglehub.dataset_download('ahsanneural/synthetic-it-support-tickets')
csv_file = [f for f in os.listdir(path) if f.endswith('.csv')][0]
df_raw = pd.read_csv(os.path.join(path, csv_file))

print(f'✅ Loaded: {df_raw.shape[0]:,} rows × {df_raw.shape[1]} columns')
df_raw.head(3)
# Out:
# ✅ Loaded: 100,000 rows × 20 columns
#      ticket_id           created_at customer_id customer_segment channel  \
# 0  TCKT_000001  2024-01-31T05:14:27  CUST_00861       individual   email
# 1  TCKT_000002  2024-10-20T06:15:49  CUST_00770       individual  in_app
# 2  TCKT_000003  2024-06-18T21:35:54  CUST_02559   small_business    chat
#
#       product_area        issue_type priority            status  sla_plan  \
# 0      data_export    account_access      low          resolved  standard
# 1          billing  security_concern   medium  closed_no_action  standard
# 2  api_integration               bug      low       in_progress  standard
#
#                                      initial_message  \
# 0  I cannot log in; the system says my password i...
# 1        I noticed a suspicious login on my account.
# 2  The api integration feature is not saving my c...
#
#                                    agent_first_reply  \
# 0  Sorry to hear you're having trouble accessing ...
# 1  We take security very seriously. Our team is r...
# 2  Thanks for reporting this bug. We will look in...
#
#                                   resolution_summary  resolution_time_hours  \
# 0  Reset account credentials and confirmed succes...                  36.53
# 1  Ticket closed without further action after no ...                 238.32
# 2                                                NaN                    NaN
#
#    reopened customer_sentiment  csat_score  has_attachment platform region
# 0         0      very_negative           1               0  android     EU
# 1         0            neutral           3               0      web    NaN
# 2         0            neutral           3               0  android    MEA
