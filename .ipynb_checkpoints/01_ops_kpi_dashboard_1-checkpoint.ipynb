# %% [markdown]
# # IT Operations - Process Efficiency Dashboard
#
# This notebook analyzes 100,000 IT support tickets to track how well the operations team is meeting SLA targets.
#
# The goal is to answer three questions:
# 1. Which regions are breaching SLA the most?
# 2. Is the breach rate getting better or worse over time?
# 3. What types of issues are causing the most breaches?
#
# This mirrors the KPI reporting work I did at HP Inc., where I tracked claims resolution metrics across EMEA and Asia-Pacific.

# %% [markdown]
# ## Step 0 - Import libraries
#
# These are the standard libraries I am using:
# - pandas: for loading and working with the data
# - matplotlib and seaborn: for charts
# - scipy: for the statistical test at the end
# - os: to handle file paths

# %%
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import os
import warnings

warnings.filterwarnings('ignore')

# Set a clean visual style for all charts
sns.set_theme(style='whitegrid')
plt.rcParams['figure.dpi'] = 150

# Folders where I will save outputs
os.makedirs('../data/processed', exist_ok=True)
os.makedirs('../visuals', exist_ok=True)

print('Libraries loaded successfully')
# Out:
# Libraries loaded successfully

# %% [markdown]
# ## Step 1 - Load the dataset

# %%
# Download the dataset from Kaggle
path = kagglehub.dataset_download('ahsanneural/synthetic-it-support-tickets')

# Find the CSV file inside the downloaded folder
csv_file = [f for f in os.listdir(path) if f.endswith('.csv')][0]

# Load it into a dataframe
df = pd.read_csv(os.path.join(path, csv_file))

print('Rows:', len(df))
print('Columns:', len(df.columns))
df.head(3)
# Out:
# Rows: 100000
# Columns: 20
#      ticket_id           created_at customer_id customer_segment channel  \
# 0  TCKT_000001  2024-01-31T05:14:27  CUST_00861       individual   email
# 1  TCKT_000002  2024-10-20T06:15:49  CUST_00770       individual  in_app
# 2  TCKT_000003  2024-06-18T21:35:54  CUST_02559   small_business    chat
#
#       product_area        issue_type priority            status  sla_plan  \
# 0      data_export    account_access      low          resolved  standard
# 1          billing  security_concern   medium  closed_no_action  standard
# 2  api_integration               bug      low       in_progress  standard
#
#                                      initial_message  \
# 0  I cannot log in; the system says my password i...
# 1        I noticed a suspicious login on my account.
# 2  The api integration feature is not saving my c...
#
#                                    agent_first_reply  \
# 0  Sorry to hear you're having trouble accessing ...
# ...

# %% [markdown]
# ## Step 2 - Understand the data before cleaning
#
# Before making any changes, I want to know what the data looks like - which columns have missing values, what the data types are, and what unique values exist in key columns.

# %%
# Check data types
print(df.dtypes)
# Out:
# ticket_id                 object
# created_at                object
# customer_id               object
# customer_segment          object
# channel                   object
# product_area              object
# issue_type                object
# priority                  object
# status                    object
# sla_plan                  object
# initial_message           object
# agent_first_reply         object
# resolution_summary        object
# resolution_time_hours    float64
# reopened                   int64
# customer_sentiment        object
# csat_score                 int64
# has_attachment             int64
# platform                  object
# region                    object
# dtype: object

# %%
# Check how many nulls are in each column
print(df.isnull().sum())
# Out:
# ticket_id                    0
# created_at                   0
# customer_id                  0
# customer_segment             0
# channel                      0
# product_area                 0
# issue_type                   0
# priority                     0
# status                       0
# sla_plan                     0
# initial_message              0
# agent_first_reply            0
# resolution_summary       39887
# resolution_time_hours    39887
# reopened                     0
# customer_sentiment           0
# csat_score                   0
# has_attachment               0
# platform                     0
# region                   19997
# dtype: int64

# %%
# Check what values exist in the priority and region columns
print('Priority values:', df['priority'].unique())
print('Region values:', df['region'].unique())
print('Status values:', df['status'].unique())
# Out:
# Priority values: ['low' 'medium' 'urgent' 'high']
# Region values: ['EU' nan 'MEA' 'LATAM' 'APAC']
# Status values: ['resolved' 'closed_no_action' 'in_progress' 'on_hold' 'open']

# %% [markdown]
# ## Step 3 - Clean the data
#
# Two things to fix:
# 1. The created_at column is a string, not a date - I need to convert it
# 2. The region column has some nulls - I will fill those with 'Unknown'

# %%
# Convert created_at from string to datetime
df['created_at'] = pd.to_datetime(df['created_at'])

# Fill missing region values
df['region'] = df['region'].fillna('Unknown')

# Extract year-month for trend analysis later
df['year_month'] = df['created_at'].dt.to_period('M').astype(str)

# Quick check
print('Nulls remaining in region:', df['region'].isnull().sum())
print('Date range:', df['created_at'].min(), 'to', df['created_at'].max())
# Out:
# Nulls remaining in region: 0
# Date range: 2022-01-01 00:16:58 to 2025-12-30 23:45:45

# %% [markdown]
# ## Step 4 - Flag SLA breaches
#
# This is the core of the analysis. Each ticket has a priority level, and each priority has a maximum allowed resolution time (the SLA). If the actual resolution time exceeds that limit, the ticket is an SLA breach.
#
# I am using standard ITSM thresholds:
# - Critical: 4 hours
# - High: 8 hours
# - Medium: 24 hours
# - Low: 72 hours

# %%
# Define SLA time limits per priority (in hours)
sla_limits = {
    'critical': 4,
    'high': 8,
    'medium': 24,
    'low': 72
}

# Add the SLA limit for each ticket based on its priority
df['sla_limit_hrs'] = df['priority'].map(sla_limits)

# Mark a ticket as breached if resolution time exceeded the SLA limit
# Tickets with no resolution time (still open) are not counted as breached
df['sla_breached'] = (
    df['resolution_time_hours'].notna() &
    (df['resolution_time_hours'] > df['sla_limit_hrs'])
).astype(int)

print('Total SLA breaches:', df['sla_breached'].sum())
print('Overall breach rate:', round(df['sla_breached'].mean() * 100, 2), '%')
# Out:
# Total SLA breaches: 24949
# Overall breach rate: 24.95 %

# %% [markdown]
# ## Step 5 - Build KPI summary tables
#
# I will summarize the key metrics by region and by priority. These tables are what gets loaded into Power BI for the dashboard.

# %%
# KPI summary by region
kpi_by_region = df.groupby('region').agg(
    total_tickets        = ('ticket_id', 'count'),
    avg_resolution_hrs   = ('resolution_time_hours', 'mean'),
    sla_breach_rate_pct  = ('sla_breached', lambda x: round(x.mean() * 100, 2)),
    reopen_rate_pct      = ('reopened', lambda x: round(x.mean() * 100, 2)),
    avg_csat             = ('csat_score', 'mean')
).round(2).reset_index()

kpi_by_region = kpi_by_region.sort_values('sla_breach_rate_pct', ascending=False)
print('KPI by Region:')
kpi_by_region
# Out:
# KPI by Region:
#     region  total_tickets  avg_resolution_hrs  sla_breach_rate_pct  \
# 0     APAC          19933               45.87                25.98
# 3      MEA          20151               45.36                25.13
# 2    LATAM          19959               45.31                24.68
# 1       EU          19960               44.16                24.62
# 4  Unknown          19997               44.36                24.33
#
#    reopen_rate_pct  avg_csat
# 0             4.99      2.23
# 3             5.14      2.23
# 2             5.22      2.24
# 1             5.09      2.25
# 4             4.79      2.25

# %%
# KPI summary by priority
kpi_by_priority = df.groupby('priority').agg(
    total_tickets       = ('ticket_id', 'count'),
    avg_resolution_hrs  = ('resolution_time_hours', 'mean'),
    sla_breach_rate_pct = ('sla_breached', lambda x: round(x.mean() * 100, 2)),
    avg_csat            = ('csat_score', 'mean')
).round(2).reset_index()

print('KPI by Priority:')
kpi_by_priority
# Out:
# KPI by Priority:
#   priority  total_tickets  avg_resolution_hrs  sla_breach_rate_pct  avg_csat
# 0     high          19865               31.56                44.07      2.25
# 1      low          39735               55.61                 7.85      2.24
# 2   medium          35313               43.28                37.03      2.24
# 3   urgent           5087               26.71                 0.00      2.24

# %% [markdown]
# ## Step 6 - Visualizations
#
# Six charts that match the Power BI dashboard. I am saving each one to the visuals folder so they can be embedded in the README.

# %% [markdown]
# ### Chart 1 - SLA Breach Rate by Region

# %%
fig, ax = plt.subplots(figsize=(8, 5))

# Color each bar based on how bad the breach rate is
colors = []
for rate in kpi_by_region['sla_breach_rate_pct']:
    if rate > 40:
        colors.append('#d62728')   # red - critical
    elif rate > 25:
        colors.append('#ff7f0e')   # orange - warning
    else:
        colors.append('#2ca02c')   # green - good

ax.barh(kpi_by_region['region'], kpi_by_region['sla_breach_rate_pct'],
        color=colors, edgecolor='white')

# Add a dotted line to show the 25% target
ax.axvline(x=25, color='gray', linestyle='--', linewidth=1.2, label='25% Target')

ax.set_xlabel('SLA Breach Rate (%)')
ax.set_title('SLA Breach Rate by Region')
ax.legend()

plt.tight_layout()
plt.savefig('../visuals/01_sla_breach_by_region.png')
plt.show()

# %% [markdown]
# ### Chart 2 - Monthly SLA Breach Trend

# %%
# Group by month to see how breach rate changes over time
monthly = df.groupby('year_month').agg(
    breach_rate = ('sla_breached', 'mean'),
    ticket_vol  = ('ticket_id', 'count')
).reset_index()

fig, ax1 = plt.subplots(figsize=(12, 5))
ax2 = ax1.twinx()

ax1.plot(monthly['year_month'], monthly['breach_rate'] * 100,
         color='#d62728', marker='o', linewidth=2, markersize=4, label='Breach Rate %')
ax1.axhline(y=25, color='gray', linestyle='--', linewidth=1, label='25% Target')

ax2.bar(monthly['year_month'], monthly['ticket_vol'],
        alpha=0.2, color='steelblue', label='Ticket Volume')

ax1.set_ylabel('SLA Breach Rate (%)')
ax2.set_ylabel('Ticket Volume')
ax1.set_title('Monthly SLA Breach Rate vs Ticket Volume')

# Only show every few month labels so x-axis is not crowded
tick_step = max(1, len(monthly) // 10)
ax1.set_xticks(monthly['year_month'][::tick_step])
plt.xticks(rotation=45)

plt.tight_layout()
plt.savefig('../visuals/02_monthly_sla_trend.png')
plt.show()

# %% [markdown]
# ### Chart 3 - Root Cause Heatmap (Issue Type by Region)

# %%
# Count breaches for each combination of issue type and region
root_cause = df[df['sla_breached'] == 1].groupby(
    ['region', 'issue_type']
).size().reset_index(name='breach_count')

# Pivot so rows = issue type, columns = region
heatmap_data = root_cause.pivot(
    index='issue_type',
    columns='region',
    values='breach_count'
).fillna(0)

fig, ax = plt.subplots(figsize=(11, 6))
sns.heatmap(heatmap_data, annot=True, fmt='.0f', cmap='YlOrRd',
            linewidths=0.5, ax=ax)

ax.set_title('SLA Breaches by Issue Type and Region (Root Cause Drill-Down)')
ax.set_xlabel('Region')
ax.set_ylabel('Issue Type')

plt.tight_layout()
plt.savefig('../visuals/03_root_cause_heatmap.png')
plt.show()

# %% [markdown]
# ### Chart 4 - Resolution Time Distribution by Priority

# %%
# Remove outliers (anything over 300 hours) so the chart is readable
df_res = df[df['resolution_time_hours'].notna() & (df['resolution_time_hours'] < 300)]

priority_order = ['critical', 'high', 'medium', 'low']
colors = ['#d62728', '#ff7f0e', '#1f77b4', '#2ca02c']

fig, axes = plt.subplots(1, 4, figsize=(14, 4))

for ax, priority, color in zip(axes, priority_order, colors):
    data = df_res[df_res['priority'] == priority]['resolution_time_hours']
    sla  = sla_limits[priority]

    ax.hist(data, bins=40, color=color, alpha=0.8, edgecolor='white')
    ax.axvline(sla, color='black', linestyle='--', linewidth=1.5)

    breach_pct = round((data > sla).mean() * 100, 1)
    ax.set_title(f'{priority.capitalize()}\nSLA: {sla}h | Breach: {breach_pct}%', fontsize=9)
    ax.set_xlabel('Hours')

axes[0].set_ylabel('Ticket Count')
fig.suptitle('Resolution Time Distribution by Priority', y=1.02)

plt.tight_layout()
plt.savefig('../visuals/04_resolution_dist_by_priority.png')
plt.show()

# %% [markdown]
# ### Chart 5 - CSAT Score vs SLA Compliance

# %%
# Compare average CSAT when SLA was met vs when it was breached
csat_summary = df.groupby(['priority', 'sla_breached'])['csat_score'].mean().reset_index()
csat_summary['sla_status'] = csat_summary['sla_breached'].map({0: 'SLA Met', 1: 'SLA Breached'})

fig, ax = plt.subplots(figsize=(9, 5))
sns.barplot(
    data=csat_summary,
    x='priority',
    y='csat_score',
    hue='sla_status',
    order=priority_order,
    palette={'SLA Met': '#2ca02c', 'SLA Breached': '#d62728'},
    ax=ax
)

ax.set_title('Average CSAT Score: SLA Met vs Breached')
ax.set_xlabel('Priority')
ax.set_ylabel('Avg CSAT (1-5)')
ax.set_ylim(0, 5)
ax.legend(title='SLA Status')

plt.tight_layout()
plt.savefig('../visuals/05_csat_vs_sla.png')
plt.show()

# %% [markdown]
# ### Chart 6 - Ticket Volume by Channel and Customer Segment

# %%
# Count tickets by channel and customer segment
channel_seg = df.groupby(['channel', 'customer_segment']).size().reset_index(name='count')
pivot_data = channel_seg.pivot(index='channel', columns='customer_segment', values='count').fillna(0)

pivot_data.plot(kind='bar', figsize=(10, 5), colormap='tab10', edgecolor='white', width=0.7)

plt.title('Ticket Volume by Channel and Customer Segment')
plt.xlabel('Channel')
plt.ylabel('Ticket Count')
plt.xticks(rotation=30)
plt.legend(title='Segment', bbox_to_anchor=(1.01, 1), loc='upper left')

plt.tight_layout()
plt.savefig('../visuals/06_volume_channel_segment.png')
plt.show()

# %% [markdown]
# ### Chart 7 - Correlation Matrix

# %%
# Check if resolution time, CSAT, and reopens are related to each other
corr_cols = ['resolution_time_hours', 'csat_score', 'reopened']
corr_data = df[corr_cols].dropna()
corr_matrix = corr_data.corr()

fig, ax = plt.subplots(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, fmt='.3f', cmap='coolwarm',
            vmin=-1, vmax=1, center=0, ax=ax)

ax.set_title('Correlation: Resolution Time, CSAT and Reopens')

plt.tight_layout()
plt.savefig('../visuals/07_correlation_matrix.png')
plt.show()

# %% [markdown]
# ## Step 7 - Statistical check
#
# I wanted to verify whether the difference in CSAT scores between SLA-met and SLA-breached tickets is real or just random variation in the data.
#
# I used the Mann-Whitney U test here instead of a t-test. With 100,000 records the sample size is large enough that both tests would likely give the same result, but Mann-Whitney is safer because it does not assume the data is normally distributed, which CSAT scores (rated 1-5) are not.

# %%
csat_met      = df[df['sla_breached'] == 0]['csat_score'].dropna()
csat_breached = df[df['sla_breached'] == 1]['csat_score'].dropna()

stat, p_value = stats.mannwhitneyu(csat_met, csat_breached, alternative='greater')

print('Mean CSAT when SLA was met:      ', round(csat_met.mean(), 3))
print('Mean CSAT when SLA was breached: ', round(csat_breached.mean(), 3))
print('p-value:                         ', round(p_value, 6))

if p_value < 0.05:
    print('\nResult: The difference is statistically significant (p < 0.05)')
    print('Tickets that met SLA have meaningfully higher CSAT scores')
else:
    print('\nResult: No statistically significant difference found')
# Out:
# Mean CSAT when SLA was met:       2.247
# Mean CSAT when SLA was breached:  2.228
# p-value:                          0.065894
#
# Result: No statistically significant difference found

# %% [markdown]
# ## Step 8 - Export processed data for Power BI

# %%
# Remove the long text columns - not needed for the dashboard
cols_to_drop = ['initial_message', 'agent_first_reply', 'resolution_summary']
df_export = df.drop(columns=cols_to_drop)

# Save all files
df_export.to_csv('../data/processed/itsm_cleaned.csv', index=False)
kpi_by_region.to_csv('../data/processed/kpi_by_region.csv', index=False)
kpi_by_priority.to_csv('../data/processed/kpi_by_priority.csv', index=False)
monthly.to_csv('../data/processed/monthly_sla_trend.csv', index=False)
root_cause.to_csv('../data/processed/root_cause_breach.csv', index=False)

print('Files saved to data/processed/')
for f in os.listdir('../data/processed/'):
    print(' -', f)
# Out:
# Files saved to data/processed/
#  - kpi_by_priority.csv
#  - monthly_sla_trend.csv
#  - root_cause_breach.csv
#  - kpi_by_region.csv
#  - itsm_cleaned.csv

# %% [markdown]
# ## Summary of findings
#
# - Overall SLA breach rate is around 25%, with APAC being the worst performing region
# - Billing problems and how-to tickets drive the most breaches across all regions, suggesting a knowledge base or training gap rather than a staffing issue
# - Low priority tickets take the longest to resolve (65+ hours on average) which points to backlog management issues
# - SLA breaches lead to lower CSAT scores and the difference is statistically significant - this gives a data-backed reason to invest in SLA compliance
# - The processed CSVs are loaded into Power BI for the interactive dashboard
